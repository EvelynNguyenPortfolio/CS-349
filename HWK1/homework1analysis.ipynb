# %% [markdown]
# <a href="https://colab.research.google.com/github/EvelynNguyenPortfolio/CS-349/blob/main/HWK1/homework1analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 1 Analysis
#
# 1. Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?
#
# First, a person should login into Google Colab. Then, depending on how a person want to interact with their github repository, they will either be transferring files from github into Google Colab or saving copies of their Google Colab notebooks into their github repository. If a person wants to transfer a github file into their Google Colab, the next step is to download the file and upload it into Google Colab. IF a person wants to save a copy their Google Colab notebook to their github repositoy, their next step is to click File in the top menu and select "Save a copy in Github". Then, the person will choos the target github repository, branch, and make the necessary adjustments to the file name and path. If a person wants to organize their notebook in their github repository using folders, they would edit the file path to include the name of the folder before the file name while saving it to github.
#
#
# 2. Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?
#
# All the notebooks executed successfully in Colab first try. I did not need to adjust any syntax or dependencies. Numpy, Pandas, and Matplotlib were all pre-installed in Google Colab, so the import commands from the notebooks worked fine.
#
# 3. Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).
#
# First, I went to my github profile dashboard. Then, I clicked the + dropdown menu in the upper-righthand corner and selected new repository. Next, I gave my repository the name "CS-349", made my visiibility private, and selected add "README" before finally clicking the green "create repository" button. I organized my files by creating directories within my github repository. When I saved a copy of the google colab notebooks to github, I ensured that I specified HWK1/ in my file path. This action saved all the notebook files under my HWK1 directory folder and allowed me to easily find all the content related to this specific homework assigment.
#
# 4. Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?
#
# It is important to establish a strong command of basic Python data structures and syntax because the training data and models we create are formatted, manipulated, and processed through the Python data structures and functions. Data is not perfect, and algorithms cannot injest raw text and data. We often need to split the data, modify it, and plot it in order to understand the data and create predictions. In other words, we need python's data structure and pre-made libraries to contain and interact with data.
